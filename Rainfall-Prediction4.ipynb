# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Machine Learning\Rainfall Prediction System\district wise rainfall normal.csv")

# %%
df.head(3)
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB   MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9  65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0  18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9   8.6   53.4
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# 1    483.5   1757.2    705.3
# 2    405.6   1884.4    574.7

# %%
df.shape
# Out:
# (641, 19)

# %%
df.isnull().sum()
# Out:
# STATE_UT_NAME    0
# DISTRICT         0
# JAN              0
# FEB              0
# MAR              0
# APR              0
# MAY              0
# JUN              0
# JUL              0
# AUG              0
# SEP              0
# OCT              0
# NOV              0
# DEC              0
# ANNUAL           0
# Jan-Feb          0
# Mar-May          0
# Jun-Sep          0
# Oct-Dec          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["STATE_UT_NAME", "Jan-Feb", "Mar-May", "Jun-Sep", "Oct-Dec"], inplace=True)

# %%
import seaborn as sns
sns.boxplot(data=df, y="DEC")
# Out:
# <Axes: ylabel='DEC'>

# %%
df["JAN"].describe()
# Out:
# count    641.000000
# mean      18.355070
# std       21.082806
# min        0.000000
# 25%        6.900000
# 50%       13.300000
# 75%       19.200000
# max      144.500000
# Name: JAN, dtype: float64

# %%
q1 =  6.9
q3 = 19.2
iqr = q3 - q1

# %%
ub = q3 + 1.5*iqr
lb = q1 - 1.5*iqr

# %%
df = df[(df["JAN"]>lb)&(df["JAN"]<ub)]
sns.boxplot(data=df, y="JAN")
# Out:
# <Axes: ylabel='JAN'>

# %%
df["FEB"].describe()
# Out:
# count    570.00000
# mean      13.64614
# std       11.48489
# min        0.00000
# 25%        5.85000
# 50%       11.15000
# 75%       18.70000
# max       79.50000
# Name: FEB, dtype: float64

# %%
q1 = 5.85
q3 = 18.70
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["FEB"]>lb)&(df["FEB"]<ub)]
sns.boxplot(data=df, y="FEB")
# Out:
# <Axes: ylabel='FEB'>

# %%
df["MAR"].describe()
# Out:
# count    550.000000
# mean      17.446545
# std       20.415213
# min        0.000000
# 25%        6.100000
# 50%       10.900000
# 75%       18.500000
# max      169.700000
# Name: MAR, dtype: float64

# %%
q1 = 6.10
q3 = 18.50
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["MAR"]>lb)&(df["MAR"]<ub)]
sns.boxplot(data=df, y="MAR")
# Out:
# <Axes: ylabel='MAR'>

# %%
df["APR"].describe()
# Out:
# count    482.000000
# mean      16.245643
# std       19.419525
# min        0.000000
# 25%        3.800000
# 50%        8.900000
# 75%       21.600000
# max      138.900000
# Name: APR, dtype: float64

# %%
q1 = 3.8
q3 = 21.6
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR 
df = df[(df["APR"]>lb)&(df["APR"]<ub)]
sns.boxplot(data=df, y="APR")
# Out:
# <Axes: ylabel='APR'>

# %%
df["MAY"].describe()
# Out:
# count    447.000000
# mean      30.259955
# std       30.828387
# min        0.900000
# 25%        9.350000
# 50%       17.800000
# 75%       44.900000
# max      217.600000
# Name: MAY, dtype: float64

# %%
q1 = 9.35
q3 = 44.90
IQR = q3 - q1 
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["MAY"]>lb)&(df["MAY"]<ub)]
sns.boxplot(data=df, y="MAY")
# Out:
# <Axes: ylabel='MAY'>

# %%
df["JUN"].describe()
# Out:
# count    431.000000
# mean     128.109745
# std      106.666725
# min        3.800000
# 25%       62.300000
# 50%      112.100000
# 75%      164.950000
# max      949.800000
# Name: JUN, dtype: float64

# %%
q1 = 62.30
q3 = 164.95
IQR = q3 - q1 
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["JUN"]>lb)&(df["JUN"]<ub)]
sns.boxplot(data=df, y="JUN")
# Out:
# <Axes: ylabel='JUN'>

# %%
df["JUL"].describe()
# Out:
# count    418.000000
# mean     256.769617
# std      103.896343
# min       11.600000
# 25%      191.125000
# 50%      270.850000
# 75%      323.675000
# max      749.800000
# Name: JUL, dtype: float64

# %%
q1 = 191.125
q3 = 323.675
IQR = q3 - q1 
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["JUL"]>lb)&(df["JUL"]<ub)]
sns.boxplot(data=df, y="JUL")
# Out:
# <Axes: ylabel='JUL'>

# %%
df['AUG'].describe()
# Out:
# count    415.000000
# mean     251.287470
# std       95.284171
# min       14.100000
# 25%      179.900000
# 50%      266.900000
# 75%      309.850000
# max      486.100000
# Name: AUG, dtype: float64

# %%
q1 = 179.90
q3 = 309.85 
IQR = q3 - q1 
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["AUG"]>lb)&(df["AUG"]<ub)]
sns.boxplot(data=df, y="AUG")
# Out:
# <Axes: ylabel='AUG'>

# %%
df["SEP"].describe()
# Out:
# count    415.000000
# mean     163.386024
# std       58.744324
# min        8.600000
# 25%      120.900000
# 50%      165.500000
# 75%      208.500000
# max      341.000000
# Name: SEP, dtype: float64

# %%
q1 = 120.90
q3 = 208.50
IQR = q3 - q1 
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["SEP"]>lb)&(df["SEP"]<ub)]
sns.boxplot(data=df, y="SEP")
# Out:
# <Axes: ylabel='SEP'>

# %%
df.columns
# Out:
# Index(['DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG',
#        'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL'],
#       dtype='str')

# %%
df["DISTRICT"].unique()
# Out:
# <ArrowStringArray>
# [      'BANKURA',       'BIRBHUM',       'BURDWAN',       'PURULIA',
#    'MURSHIDABAD',         'NADIA',      'BOLANGIR', 'KANDHAMAL/PHU',
#        'CUTTACK',     'DHENKANAL',
#  ...
#          'GADAG',        'HAVERI',        'KOPPAL', 'BANGALORE RUR',
#        'BELLARY',   'CHITRADURGA',         'KOLAR',        'TUMKUR',
#      'DAVANGERE', 'CHICKBALLAPUR']
# Length: 412, dtype: str

# %%
df["OCT"].describe()
# Out:
# count    414.000000
# mean      62.466425
# std       50.895935
# min        3.100000
# 25%       27.875000
# 50%       48.250000
# 75%       75.875000
# max      270.700000
# Name: OCT, dtype: float64

# %%
q1 = 27.875
q3 = 75.875 
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR 
df = df[(df["OCT"]>lb)&(df["OCT"]<ub)]
sns.boxplot(data=df, y="OCT")
# Out:
# <Axes: ylabel='OCT'>

# %%
df["NOV"].describe()
# Out:
# count    379.000000
# mean      10.831135
# std       11.948715
# min        1.200000
# 25%        4.850000
# 50%        7.800000
# 75%       12.650000
# max      120.000000
# Name: NOV, dtype: float64

# %%
q1= 4.85
q3 = 12.65
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR 
df = df[(df["NOV"]>lb)&(df["NOV"]<ub)]
sns.boxplot(data=df, y="NOV")
# Out:
# <Axes: ylabel='NOV'>

# %%
df["DEC"].describe()
# Out:
# count    351.000000
# mean       6.491453
# std        3.392131
# min        0.400000
# 25%        4.300000
# 50%        6.000000
# 75%        8.150000
# max       20.700000
# Name: DEC, dtype: float64

# %%
q1 = 4.30
q3 = 8.15
IQR = q3 - q1

# %%
ub = q3+ 1.5*IQR 
lb = q1 - 1.5*IQR 
df = df[(df["DEC"]>lb)&(df["DEC"]<ub)]
sns.boxplot(data=df, y="DEC")
# Out:
# <Axes: ylabel='DEC'>

# %%
df.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY         JUN  \
# count  337.000000  337.000000  337.000000  337.000000  337.000000  337.000000
# mean    11.845401    9.948961    9.564688    8.448665   20.026409  116.242433
# std      6.644120    6.029457    5.758268    7.938255   18.183903   58.089281
# min      0.000000    0.000000    0.100000    0.100000    0.900000    3.800000
# 25%      6.700000    5.500000    5.300000    3.000000    8.200000   64.700000
# 50%     12.400000    9.700000    9.100000    5.700000   13.900000  112.200000
# 75%     16.600000   14.500000   13.000000   10.400000   24.000000  161.000000
# max     34.200000   26.800000   25.800000   42.100000   96.000000  258.300000
#
#               JUL         AUG         SEP         OCT         NOV         DEC  \
# count  337.000000  337.000000  337.000000  337.000000  337.000000  337.000000
# mean   273.612463  268.623739  165.520475   45.594955    8.427596    6.084570
# ...

# %%
df.drop(columns=["DISTRICT"], inplace=True)

# %%
x = df.drop(columns=["ANNUAL"])
y = df["ANNUAL"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict1 = dtr.predict(X_test)

# %%
dtr.score(X_train, y_train)
# Out:
# 1.0

# %%
dtr.score(X_test, y_test)
# Out:
# 0.9657035043325723

# %%
from sklearn.ensemble import RandomForestRegressor 
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict1 = rf.predict(X_test)

# %%
rf.score(X_train, y_train)
# Out:
# 0.9975127305911029

# %%
rf.score(X_test, y_test)
# Out:
# 0.9841780470520723

# %%
import joblib 
joblib.dump(rf, "rainfall4.pkl")
print("Model saved as rainfall4.pkl")
# Out:
# Model saved as rainfall4.pkl
