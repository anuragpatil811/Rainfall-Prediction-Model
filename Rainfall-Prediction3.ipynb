# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Machine Learning\Rainfall Prediction System\usa_rain_prediction_dataset_2024_2025.csv")
df.head(3)
# Out:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  2024-01-01  New York    87.524795  75.655455   28.379506       0.000000
# 1  2024-01-02  New York    83.259325  28.712617   12.436433       0.526995
# 2  2024-01-03  New York    80.943050  64.740043   14.184831       0.916884
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278              0
# 1    41.606048   995.962065              0
# 2    77.364763   980.796739              1

# %%
df.shape
# Out:
# (73100, 9)

# %%
df.drop(columns=["Date", "Location"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Temperature      0
# Humidity         0
# Wind Speed       0
# Precipitation    0
# Cloud Cover      0
# Pressure         0
# Rain Tomorrow    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns 
sns.boxplot(data=df, y="Precipitation")
# Out:
# <Axes: ylabel='Precipitation'>

# %%
df["Precipitation"].describe()
# Out:
# count    73100.000000
# mean         0.390635
# std          0.474833
# min          0.000000
# 25%          0.000000
# 50%          0.196909
# 75%          0.673177
# max          3.078090
# Name: Precipitation, dtype: float64

# %%
q1 = 0.000000
q3 = 0.673177
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Precipitation"]>lb)&(df["Precipitation"]<ub)]

# %%
sns.boxplot(data=df, y="Precipitation")
# Out:
# <Axes: ylabel='Precipitation'>

# %%
sns.boxplot(data=df, y="Pressure")
# Out:
# <Axes: ylabel='Pressure'>

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation   Cloud Cover  \
# count  71908.000000  71908.000000  71908.000000   71908.000000  71908.000000
# mean      65.171250     59.860355     15.021533       0.365047     54.936851
# std       20.198127     23.057241      8.669001       0.433794     25.982603
# min       30.000766     20.000272      0.000712       0.000000     10.000856
# 25%       47.667817     39.798420      7.486415       0.000000     32.313481
# 50%       65.289718     59.847382     15.110402       0.183904     54.995302
# 75%       82.612040     79.816367     22.555659       0.646722     77.412469
# max       99.997393     99.999025     29.999017       1.682787     99.998957
#
#            Pressure  Rain Tomorrow
# count  71908.000000   71908.000000
# mean    1005.187893       0.215317
# std       20.207226       0.411045
# min      970.000919       0.000000
# 25%      987.699418       0.000000
# 50%     1005.306929       0.000000
# ...

# %%
x = df.drop("Rain Tomorrow", axis=1)
y = df["Rain Tomorrow"]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression 
log = LogisticRegression()
log.fit(X_train, y_train)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict = log.predict(X_test)

# %%
log.score(X_train, y_train)
# Out:
# 0.9091367381705664

# %%
log.score(X_test, y_test)
# Out:
# 0.910095953274927

# %%
from sklearn.tree import DecisionTreeClassifier 
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict1 = dt.predict(X_test)

# %%
dt.score(X_train, y_train)
# Out:
# 1.0

# %%
dt.score(X_test, y_test)
# Out:
# 1.0

# %%
import pickle
with open("rainfall3.pkl", "wb") as f:
    pickle.dump(dt, f)
